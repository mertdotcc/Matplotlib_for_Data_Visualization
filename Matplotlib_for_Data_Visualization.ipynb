# %% [markdown]
# # Matplotlib

# %% [markdown]
# - Matplotlib is the most popular plotting library for Python.
# - It gives us control over every aspect of a figure.
# - It was designed to have a similar feel to Matlab's graphical plotting.
# - Matplotlib works very well with Pandas and NumPy arrays.
# - Another visualization library Seaborn is actually built on top of Matplotlib.
#
# To install it, if you are using Anaconda Distribution:
#
# conta install matplotlib
#
# __or__ (regular command line)
#
# pip install matplotlib
#
# __Always refer to the gallery section of the official Matplotlib website for ideas/inspirations:__ https://matplotlib.org/gallery/index.html

# %%
import matplotlib.pyplot as plt

# %%
# To be able to see the plots created by matplotlib inside of our jupyter notebook file.
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional method
plt.plot(x,y)

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'g')

# %%
plt.plot(x,y,'g-')

# %%
plt.plot(x,y,'g--')

# %%
plt.plot(x,y)
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# __Putting multi plots on the same canvas.__

# %%
plt.subplot(1,2,1) # row number, column number, the current graph we are referring to
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# The object-oriented method
fig = plt.figure()

# So we have created a figure object. Now we are going to use the
# built-in functions that comes with a figure object and deal
# with our graphs in an object-oriented approach.

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x,y)

axes.set_xlabel("X Label")
axes.set_ylabel("Y Label")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.15,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.8,0.15,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.5,0.15,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title("BIGGER PLOT")

axes2.plot(y,x)
axes2.set_xlabel("X Label")
axes2.set_ylabel("Y Label")
axes2.set_title("SMALLER PLOT")
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig, axes = plt.subplots(nrows=3, ncols=3)

# %%
fig, axes = plt.subplots(nrows=3, ncols=3)
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y)
axes[0].set_title("First Plot")

axes[1].plot(y,x)
axes[1].set_title("Second Plot")

# It is a good programming practice to put the next line everytime we are plotting a graph.
plt.tight_layout()

# %% [markdown]
# # Figure Size, Aspect Ratio and DPI

# %% [markdown]
# DPI stands for: Dots per inch (or pixels per inch)

# %%
fig = plt.figure(figsize=(3,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig, axes = plt.subplots(figsize=(8,2))

axes.plot(x,y)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %% [markdown]
# # Saving a figure

# %%
fig

# %% [markdown]
# To save the figure into our computer, we simply call a function and set the name we want the figure to be names as.
#
# We also decide on which format we want our figure to be saved as, such as JPEG, PNG etc.

# %%
fig.savefig('my_fig.png')

# %% [markdown]
# ### Adding a legend.

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, label='X Squared')
ax.plot(x, x**3, label="X Cubed")

ax.legend(loc=0)

# %%
# Use the following parameters values for positioning the legend.
from IPython.display import Image
Image(filename="i3.png")

# %% [markdown]
# # Plot Appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# By putting in the color parameter, we can change the color of the plot.
ax.plot(x, y, color='orange')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# By putting in the color parameter, we can change the color of the plot.
ax.plot(x, y, color='#FF8C00')

# %% [markdown]
# __Line width and line style.__

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# Linewidth parameter is by default set to 1.
ax.plot(x, y, color='purple', linewidth=5)

# %% [markdown]
# __Transperancy__

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# Linewidth parameter is by default set to 1.
ax.plot(x, y, color='purple', linewidth=5, alpha=0.5)

# %% [markdown]
# __Line style__

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=5, linestyle='--')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=5, linestyle='-.')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=5, linestyle=':')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=5, linestyle='steps')

# %% [markdown]
# ## Markers.

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=5, linestyle='-', marker='o', alpha=0.5)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=0.5, linestyle='-', marker='+', alpha=0.5)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=0.5, linestyle='-', marker='+', markersize=20, alpha=0.5)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=1, linestyle='-', marker='o', markersize=20, alpha=1)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color='purple', linewidth=1, linestyle='-', marker='o', markersize=20, markerfacecolor='yellow', 
                        markeredgewidth=3, markeredgecolor='green', alpha=1)

# %% [markdown]
# # Line and Marker styles

# %% [markdown]
# To change the line width, we can use the `linewidth` or `lw` keyword argument. The line style can be selected using the `linestyle` or `ls` keyword arguments:

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# # Special Plot types

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000), 100)
plt.hist(data)
# Out:
# (array([12.,  9., 11., 12., 10.,  8.,  7., 10., 13.,  8.]),
#  array([  1. , 100.3, 199.6, 298.9, 398.2, 497.5, 596.8, 696.1, 795.4,
#         894.7, 994. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]

# Rectangular box plot
plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x82cd81b320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x82cd81ba58>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x82cd810f28>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x82cd81be80>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x82cd825470>,
# ...
#  'means': []}

# %% [markdown]
# A good source to refer: https://github.com/rougier/matplotlib-tutorial
